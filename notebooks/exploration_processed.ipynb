# %%
import pandas as pd

# %%
trainingDf = pd.read_csv("../data/processed/training.csv")

print(trainingDf.dtypes)
print(trainingDf.head())
print(trainingDf.describe())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 trainingDf = pd.read_csv("../data/processed/training.csv")
# ----> 3 print(trainingDf.dtypes())
#       4 print(trainingDf.head())
#       5 print(trainingDf.describe())
#
# TypeError: 'Series' object is not callable
