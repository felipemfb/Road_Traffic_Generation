# %%
import pandas as pd

# %%
trainingDf = pd.read_csv("../data/processed/training.csv")

print(trainingDf.dtypes)
print(trainingDf.head())
print(trainingDf.describe())
# Out:
# street_length       float64
# road_type            object
# landuse              object
# place                 int64
# centrality          float64
# num_begin_links       int64
# num_out_links         int64
# landuse_way_dest     object
# place_way_dest      float64
# max_speed           float64
# lanes                 int64
# angle               float64
# hour                  int64
# is_weekend            int64
# speed               float64
# dtype: object
#    street_length    road_type       landuse  place  centrality  \
# 0         84.295     tertiary   residential      2   -0.720508
# 1        147.286  residential  construction      2   -2.140452
# 2        147.286  residential  construction      2   -2.140452
# 3        147.286  residential  construction      2   -2.140452
# 4        147.286  residential  construction      2   -2.140452
#
#    num_begin_links  num_out_links landuse_way_dest  place_way_dest  max_speed  \
# ...

# %%
trainingDf.isna().sum()
# Out:
# street_length       2149844
# road_type           2149844
# landuse             2149844
# place               2149844
# centrality          2149844
# num_begin_links     2149844
# num_out_links       2149844
# landuse_way_dest    2149844
# place_way_dest      2149844
# max_speed           2149844
# lanes               2149844
# angle               2149844
# hour                2149844
# is_weekend          2149844
# speed               2149844
# dtype: int64
